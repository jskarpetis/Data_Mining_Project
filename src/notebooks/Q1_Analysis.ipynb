# %% [markdown]
# ## Question 1 Notebook : Merge and Analysis of demands and sources

# %% [markdown]
# Libraries

# %%
import pandas as pd

from matplotlib import pyplot as plt

# %% [markdown]
# Functions

# %%
def plot_data(dF):
    figure, axis = plt.subplots(4,4, figsize=(7,7))
    figure.tight_layout()
    columns = dF.columns.tolist()
    row = 0

    for index, elem in enumerate(columns):

        axis[row, index%4].plot(dF[elem])
        axis[row, index%4].set_title(elem)
        if (index%4 == 3):
            row += 1
    plt.show()

# %% [markdown]
# Loading Dataset and Selecting needed fields

# %%
final_dataset = pd.read_csv('../../dataset/final_dataset.csv')
df = final_dataset.loc[:,['Day ahead forecast', 'Hour ahead forecast', 
                        'Current demand', 'Solar', 'Wind', 'Geothermal', 
                        'Biomass', 'Biogas', 'Small hydro', 'Coal', 
                        'Nuclear', 'Natural gas', 'Large hydro', 
                        'Batteries', 'Imports', 'Other']]

# %% [markdown]
# Basic Statistics and Plots of dataset

# %%
print('Final stats : \n {}'.format(df.describe()))

plot_data(df)
# Out:
# Final stats :
#         Day ahead forecast  Hour ahead forecast  Current demand          Solar  \
# count       315600.000000        315624.000000   315596.000000  315605.000000
# mean         24956.050013         24840.003279    24827.962490    3560.486640
# std           4950.690630          4857.359564     4866.579171    4373.681632
# min          15053.000000             0.000000    -2651.000000    -145.000000
# 25%          21402.000000         21370.000000    21355.000000     -34.000000
# 50%          23955.500000         23889.000000    23871.000000     114.000000
# 75%          26953.000000         26828.000000    26813.000000    7969.000000
# max          50485.000000         47697.000000    72922.000000   13191.000000
#
#                 Wind     Geothermal        Biomass         Biogas  \
# count  315605.000000  315317.000000  315605.000000  315605.000000
# mean     2021.717102     890.270645     311.255481     212.566677
# std      1300.609731     115.980026      48.244031      15.383061
# min     -2476.000000    -134.000000     125.000000     101.000000
# 25%       869.000000     866.000000     279.000000     204.000000
# 50%      1833.000000     909.000000     315.000000     213.000000
# 75%      3053.000000     958.000000     344.000000     222.000000
# max     36275.000000    1134.000000     499.000000     267.000000
#
#          Small hydro           Coal        Nuclear    Natural gas  \
# count  315605.000000  315605.000000  315605.000000  315317.000000
# mean      264.014062      14.244201    1866.848678    8295.327765
# std       778.092909       4.574618     578.829856    3972.648572
# min     -2826.000000      -8.000000     -74.000000 -280718.000000
# 25%       166.000000      11.000000    1145.000000    5483.000000
# 50%       227.000000      15.000000    2259.000000    8004.000000
# 75%       338.000000      18.000000    2269.000000   10376.000000
# max    431490.000000      30.000000    2290.000000   26540.000000
#
#          Large hydro      Batteries        Imports          Other
# count  315605.000000  315605.000000  315317.000000  315605.000000
# mean     1897.535578      -5.021654    6029.378971       0.001125
# std      1288.851764     191.048792    2614.736981       0.033520
# min      -576.000000   -1614.000000  -22949.000000       0.000000
# 25%       908.000000     -31.000000    4251.000000       0.000000
# 50%      1551.000000      -3.000000    6466.000000       0.000000
# 75%      2733.000000      17.000000    8070.000000       0.000000
# max      6362.000000    1479.000000   11832.000000       1.000000
