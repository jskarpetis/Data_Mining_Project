# %% [markdown]
# ## Question 1 Notebook : Merge and Analysis of demands and sources

# %% [markdown]
# Libraries

# %%
import pandas as pd

from matplotlib import pyplot as plt

# %% [markdown]
# Functions

# %%
def plot_data(dF):
    figure, axis = plt.subplots(4,4, figsize=(7,7))
    figure.tight_layout()
    columns = dF.columns.tolist()
    row = 0

    for index, elem in enumerate(columns):

        axis[row, index%4].plot(dF[elem])
        axis[row, index%4].set_title(elem)
        if (index%4 == 3):
            row += 1
    plt.show()

# %% [markdown]
# Loading Dataset and Selecting needed fields

# %%
final_dataset = pd.read_csv('../../dataset/final_dataset.csv')
df = final_dataset.loc[:,['Day ahead forecast', 'Hour ahead forecast', 
                        'Current demand', 'Solar', 'Wind', 'Geothermal', 
                        'Biomass', 'Biogas', 'Small hydro', 'Coal', 
                        'Nuclear', 'Natural gas', 'Large hydro', 
                        'Batteries', 'Imports', 'Other']]

# %% [markdown]
# Basic Statistics and Plots of dataset

# %%
print('Final stats : \n {}'.format(df.describe()))

plot_data(df)
# Out:
# Final stats :
#         Day ahead forecast  Hour ahead forecast  Current demand          Solar  \
# count       315648.000000        315648.000000   315648.000000  315648.000000
# mean         24952.254993         24838.114593    24823.872320    3560.001603
# std           4959.869476          4862.001598     4876.599774    4373.581122
# min              0.000000             0.000000    -2651.000000    -145.000000
# 25%          21400.750000         21369.000000    21354.000000     -34.000000
# 50%          23954.000000         23889.000000    23870.000000     114.000000
# 75%          26952.250000         26827.000000    26813.000000    7969.000000
# max          50485.000000         47697.000000    72922.000000   13191.000000
#
#                 Wind     Geothermal        Biomass         Biogas  \
# count  315648.000000  315648.000000  315648.000000  315648.000000
# mean     2021.441688     889.337075     311.213079     212.537719
# std      1300.735163     119.446733      48.377323      15.580786
# min     -2476.000000    -134.000000       0.000000       0.000000
# 25%       869.000000     866.000000     279.000000     204.000000
# 50%      1833.000000     909.000000     315.000000     213.000000
# 75%      3053.000000     958.000000     344.000000     222.000000
# max     36275.000000    1134.000000     499.000000     267.000000
#
#          Small hydro           Coal        Nuclear    Natural gas  \
# count  315648.000000  315648.000000  315648.000000  315648.000000
# mean      263.978096      14.242260    1866.594361    8286.628982
# std       778.046009       4.577326     579.200368    3979.632009
# min     -2826.000000      -8.000000     -74.000000 -280718.000000
# 25%       166.000000      11.000000    1145.000000    5474.000000
# 50%       227.000000      15.000000    2259.000000    8000.000000
# 75%       338.000000      18.000000    2269.000000   10373.000000
# max    431490.000000      30.000000    2290.000000   26540.000000
#
#          Large hydro      Batteries        Imports          Other
# count  315648.000000  315648.000000  315648.000000  315648.000000
# mean     1897.277081      -5.020970    6023.056344       0.001125
# std      1288.954234     191.035788    2620.641476       0.033517
# min      -576.000000   -1614.000000  -22949.000000       0.000000
# 25%       908.000000     -31.000000    4242.000000       0.000000
# 50%      1551.000000      -3.000000    6463.000000       0.000000
# 75%      2733.000000      17.000000    8068.000000       0.000000
# max      6362.000000    1479.000000   11832.000000       1.000000
